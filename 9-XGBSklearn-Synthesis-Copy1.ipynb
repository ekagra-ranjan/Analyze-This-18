# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt

# %%
game_csv = pd.read_csv('./data/Training_dataset_Original.csv',na_values=["NA", "na", "missing"])
gameDf = pd.DataFrame(game_csv)

dataDict = pd.read_csv('./data/Data_Dictionary.csv',na_values="NA")

#Leaderboard
leader_csv = pd.read_csv('./data/Leaderboard_dataset.csv',na_values=["NA", "na", "missing"])
leaderDf = pd.DataFrame(leader_csv)

# %%
gameDf.assign(mv=0)
# Out:
#         mvar1   mvar2   mvar3  mvar4  mvar5    mvar6     mvar7     mvar8  \
# 0      1696.0  1.6541   0.000  0.000  0.000      0.0    6015.0     322.0
# 1      1846.0  0.8095   0.000  0.000  0.000    102.0    7532.0    3171.0
# 2      1745.0  0.4001   0.000  0.000  0.000      NaN    2536.0       NaN
# 3      1739.0  0.2193   0.000  0.000  0.000   1982.0   26440.0    4955.0
# 4      1787.0  0.0118   0.225  0.000  0.000   5451.0    5494.0    5494.0
# 5      1579.0     NaN   3.502  0.000  0.000      NaN       NaN       NaN
# 6      1818.0  0.4001   0.000  0.000  0.000      NaN    1088.0       NaN
# 7         NaN     NaN     NaN    NaN    NaN      NaN       NaN       NaN
# 8      1836.0  0.1358   0.000  0.000  0.000    347.0   38964.0   17828.0
# 9      1839.0  0.1981   0.000  0.000  0.000    793.0    6131.0    6045.0
# 10     1903.0  0.0000   0.000  0.000  0.000     22.0   19518.0    9910.0
# 11     1681.0  1.5888   5.685  3.566  0.000     93.0    3554.0     439.0
# 12     1841.0  0.5388   0.000  0.000  0.000   1487.0   19449.0   19449.0
# 13     1794.0  1.9684   0.000  0.000  0.000    856.0    8609.0    8609.0
# 14     1669.0  3.8558  18.465  6.292  1.200      NaN     142.0       NaN
# 15     1583.0  3.0284  16.325  0.000  0.000      NaN       NaN       NaN
# 16     1899.0  0.0970   0.000  0.000  0.000   1015.0   13379.0   13379.0
# 17     1690.0  8.7747  10.437  0.000  0.000    122.0     623.0     299.0
# 18     1599.0  0.8601   1.525  1.525  0.000      NaN     878.0       NaN
# 19     1859.0  0.0155   0.368  0.000  0.000    424.0   86509.0   12451.0
# 20     1880.0  2.6101   0.000  0.000  0.000      0.0   19252.0    6342.0
# 21     1852.0  3.6201   0.000  0.000  0.000    799.0   16515.0   16515.0
# 22     1655.0  3.0268  14.748  0.000  0.000     48.0      48.0      48.0
# 23     1863.0  0.0401   0.000  0.000  0.000   1487.0    4955.0    4955.0
# 24     1753.0  0.2251   0.000  0.000  0.000   1124.0    1124.0    1124.0
# 25     1894.0  0.0318   0.000  0.000  0.000   4655.0    7433.0    7433.0
# 26     1803.0  0.3993   0.000  0.000  0.000    496.0   10505.0     496.0
# 27     1932.0  0.3276   0.000  0.000  0.000   6982.0   21569.0   18829.0
# 28     1714.0  5.1904   0.770  0.000  0.000      0.0    1889.0     595.0
# 29        NaN  2.0457   4.514  0.000  0.000      NaN       NaN       NaN
# ...       ...     ...     ...    ...    ...      ...       ...       ...
# 79970  1834.0  1.2164   0.000  0.000  0.000   2212.0    5244.0    4203.0
# 79971  1729.0  1.3696   0.000  0.000  0.000    356.0    4218.0    1982.0
# 79972  1753.0  5.8283   0.000  0.000  0.000    180.0    4014.0     617.0
# 79973  1748.0  1.9635   0.642  0.000  0.000    291.0    3469.0    3469.0
# 79974  1771.0  1.7588   0.000  0.000  0.000     66.0   12626.0    6433.0
# 79975  1766.0  0.9540   0.000  0.000  0.000   1140.0   10207.0   10207.0
# 79976  1822.0  0.0000   1.853  1.853  0.000   2581.0   13361.0    5946.0
# 79977  1824.0  0.5634   0.000  0.000  0.000   3964.0    4683.0    4683.0
# 79978  1914.0  0.0544   0.000  0.000  0.000   3469.0   20424.0   20424.0
# 79979  1600.0  2.6649  18.282  1.078  2.678      0.0    7205.0       0.0
# 79980  1822.0  0.5851   0.000  0.000  0.000      0.0   23685.0   23685.0
# 79981  1693.0  0.1828  17.767  2.024  0.000    114.0   27514.0     384.0
# 79982  1735.0  3.1701   0.260  0.000  0.000    117.0     892.0     117.0
# 79983  1671.0  0.1380   0.000  0.000  0.000      NaN     491.0       NaN
# 79984  1924.0  0.1221   0.000  0.000  0.000   2478.0  266683.0  266683.0
# 79985  1670.0  0.0347   9.836  0.000  0.000    212.0    7848.0     491.0
# 79986  1901.0  0.1782   0.000  0.000  0.000   4955.0   21753.0   12673.0
# 79987  1835.0  0.5372   0.000  0.000  0.000      0.0   29723.0    3964.0
# 79988  1927.0  0.0410   0.000  0.000  0.000  22000.0   30046.0   24165.0
# 79989     NaN  0.1451   0.000  0.000  0.000      NaN       NaN       NaN
# 79990  1941.0  0.4834   0.000  0.000  0.000  10846.0   52806.0   35478.0
# 79991  1899.0     NaN   0.000  0.000  0.000   7310.0   14519.0   14519.0
# 79992  1761.0  2.0999   0.000  0.000  0.000     47.0   13477.0    1814.0
# 79993  1700.0  0.3831   0.000  0.000  0.000    344.0     344.0     344.0
# 79994  1910.0  0.0000   0.000  0.000  0.000   4955.0   47306.0   47306.0
# 79995  1736.0  2.1740   0.000  0.000  0.000     11.0    4248.0    1577.0
# 79996  1724.0  0.0000   1.108  0.768  0.000      NaN   64041.0       NaN
# 79997  1605.0  0.2901  11.561  0.937  2.976      NaN    2277.0       NaN
# 79998  1780.0  1.1874   0.000  0.000  0.000      0.0    6356.0    4802.0
# 79999  1727.0  1.9288   1.441  0.000  0.000      0.0   25773.0    2869.0
#
#           mvar9    mvar10 ...   mvar40  mvar41   mvar42  mvar43   mvar44  \
# 0       40369.0   18414.0 ...   73.780  82.547  0.08696    10.0  0.63899
# 1       18234.0   13664.0 ...   99.129     NaN  0.00000    13.0  0.63836
# 2           NaN    2536.0 ...      NaN  29.290  0.00000     1.0  1.00000
# 3       20316.0   37013.0 ...   96.272     NaN  0.15385     3.0  0.53241
# 4        7987.0    4696.0 ...  115.019     NaN  0.00000     1.0  0.92665
# 5           NaN       0.0 ...      NaN     NaN  1.50000     0.0      NaN
# 6        1536.0    1498.0 ...   88.171     NaN  0.00000     2.0  0.87224
# 7           NaN       NaN ...      NaN     NaN      NaN     NaN      NaN
# 8       70729.0   65843.0 ...      NaN     NaN  0.00000    10.0  0.89868
# 9       48959.0   31640.0 ...      NaN  45.590  0.08824    14.0  0.33834
# 10      90618.0  110271.0 ...      NaN     NaN  0.00000    17.0  0.80620
# 11       2527.0    7086.0 ...      NaN     NaN  0.61111     7.0  0.81172
# 12       6739.0    6612.0 ...      NaN     NaN  0.00000     5.0  0.98031
# 13      60545.0   24893.0 ...      NaN     NaN  0.00000    13.0  0.35724
# 14         38.0     142.0 ...  107.825  98.664  0.56000    11.0  0.29169
# 15      51450.0       0.0 ...      NaN     NaN  0.32353     2.0      NaN
# 16     246906.0   56533.0 ...   10.384     NaN  0.00000    19.0  0.47480
# 17       1140.0    2043.0 ...      NaN     NaN  0.63636     5.0  0.94951
# 18          NaN     878.0 ...      NaN  91.175  0.80000     0.0  1.00000
# 19      86635.0  142081.0 ...      NaN     NaN  0.00000    12.0  0.34730
# 20      59601.0   86906.0 ...      NaN  72.497  0.00000    14.0  0.28708
# 21     110651.0   41311.0 ...      NaN     NaN  0.00000    13.0  0.75349
# 22        198.0      48.0 ...      NaN     NaN  1.00000     1.0  1.00000
# 23      22902.0   21772.0 ...   96.895     NaN  0.00000    12.0  0.40853
# 24          0.0    1124.0 ...      NaN     NaN      NaN     0.0  1.00000
# 25      25667.0   12345.0 ...      NaN   0.000  0.00000     3.0  0.99419
# 26        991.0   18163.0 ...   91.752  87.306  0.20000     5.0  0.75289
# 27     187209.0  113813.0 ...      NaN     NaN  0.00000    11.0  0.99710
# 28      12574.0    4825.0 ...      NaN     NaN  0.35714     6.0  0.85082
# 29          NaN       0.0 ...      NaN     NaN  1.16667     0.0      NaN
# ...         ...       ... ...      ...     ...      ...     ...      ...
# 79970   16743.0   13831.0 ...      NaN  97.398  0.00000     8.0  0.58040
# 79971   18657.0    8921.0 ...      NaN  83.663  0.09091     6.0  0.62632
# 79972    3667.0    9786.0 ...      NaN  87.094  0.11111     9.0  0.59364
# 79973   13131.0   14393.0 ...      NaN  92.244  0.44000    14.0  0.83809
# 79974   27946.0   24401.0 ...      NaN  40.477  0.00000    10.0  0.46863
# 79975   55001.0   20636.0 ...      NaN     NaN  0.05000    14.0  0.54754
# 79976   31018.0   76774.0 ...   73.611  44.656  0.03448    20.0  0.23177
# 79977       NaN    8647.0 ...      NaN     NaN      NaN     NaN  0.67222
# 79978   78774.0   27856.0 ...      NaN     NaN  0.00000     8.0  1.00000
# 79979     956.0    7360.0 ...  132.335  56.867  0.55263    14.0  0.11763
# 79980  208174.0   55719.0 ...      NaN     NaN  0.00000    17.0  0.81438
# 79981    2329.0   48080.0 ...   74.814     NaN  0.17857     5.0  0.53340
# 79982    3766.0    1265.0 ...      NaN  99.026  0.00000     2.0  0.96747
# 79983       NaN     491.0 ...      NaN     NaN  0.80000     2.0  1.00000
# 79984  405300.0  390558.0 ...      NaN  70.799  0.00000    13.0  0.75322
# 79985   29785.0   16226.0 ...      NaN  78.700  0.13636    10.0  0.85771
# 79986   70293.0   62980.0 ...      NaN  61.301  0.00000    10.0  0.86356
# 79987   66770.0   85900.0 ...      NaN     NaN  0.00000     9.0  0.41685
# 79988   75019.0   88343.0 ...      NaN  19.444  0.00000     7.0  0.53750
# 79989       NaN       0.0 ...      NaN     NaN  1.50000     0.0      NaN
# 79990  136461.0  176240.0 ...      NaN     NaN  0.05882     8.0  0.84170
# 79991    5252.0    4949.0 ...      NaN     NaN  0.00000     3.0  0.44615
# 79992    9320.0    2500.0 ...      NaN     NaN  0.12500     5.0  0.73640
# 79993     991.0     344.0 ...      NaN     NaN  0.66667     2.0  0.97374
# 79994   88124.0  107148.0 ...      NaN     NaN  0.00000     4.0  0.79867
# 79995   13379.0    6671.0 ...      NaN  78.378  0.00000     4.0  0.43829
# 79996   10926.0   84839.0 ...      NaN  38.325  0.16667    14.0  0.57931
# 79997    3964.0    5709.0 ...  101.850  93.142  0.50000     4.0  0.42069
# 79998    3206.0   18180.0 ...      NaN  77.022  0.06061     9.0  0.53251
# 79999  132985.0   71788.0 ...   32.400     NaN  0.07143    12.0  0.68482
#
#        mvar45  mvar46  mvar47  default_ind  mv
# 0         NaN     0.0       C            0   0
# 1         NaN     NaN       L            1   0
# 2         NaN     0.0       C            1   0
# 3         0.0     0.0       L            0   0
# 4         NaN     NaN       L            0   0
# 5         NaN     NaN       C            1   0
# 6         NaN     0.0       C            1   0
# 7         NaN     NaN       C            0   0
# 8         0.0     0.0       L            0   0
# 9         NaN     0.0       L            0   0
# 10        0.0     0.0       L            0   0
# 11        0.0     0.0       C            0   0
# 12        NaN     NaN       C            0   0
# 13        NaN     0.0       C            0   0
# 14        NaN     1.0       C            0   0
# 15        0.0     NaN       C            0   0
# 16        0.0     0.0       L            0   0
# 17        NaN     0.0       L            0   0
# 18        NaN     0.0       C            1   0
# 19        0.0     0.0       L            0   0
# 20        NaN     0.0       L            0   0
# 21        NaN     NaN       L            0   0
# 22        NaN     NaN       C            1   0
# 23        NaN     0.0       L            0   0
# 24        NaN     NaN       C            1   0
# 25        0.0     0.0       L            0   0
# 26        0.0     0.0       L            0   0
# 27        0.0     0.0       C            0   0
# 28        0.0     0.0       L            0   0
# 29        NaN     NaN       L            0   0
# ...       ...     ...     ...          ...  ..
# 79970     NaN     0.0       C            0   0
# 79971     0.0     0.0       C            0   0
# 79972     NaN     0.0       L            0   0
# 79973     0.0     0.0       L            0   0
# 79974     NaN     0.0       C            0   0
# 79975     NaN     NaN       C            0   0
# 79976     NaN     0.0       C            0   0
# 79977     NaN     NaN       C            0   0
# 79978     0.0     0.0       L            0   0
# 79979     NaN     0.0       L            1   0
# 79980     0.0     NaN       L            0   0
# 79981     NaN     0.0       C            0   0
# 79982     NaN     0.0       C            1   0
# 79983     NaN     NaN       C            0   0
# 79984     0.0     0.0       L            0   0
# 79985     NaN     0.0       L            0   0
# 79986     0.0     0.0       L            0   0
# 79987     0.0     0.0       L            0   0
# 79988     0.0     0.0       L            0   0
# 79989     NaN     NaN       L            0   0
# 79990     0.0     0.0       L            0   0
# 79991     NaN     NaN       L            0   0
# 79992     0.0     0.0       C            1   0
# 79993     0.0     0.0       C            1   0
# 79994     NaN     NaN       L            0   0
# 79995     NaN     0.0       C            0   0
# 79996     0.0     0.0       C            0   0
# 79997     NaN     0.0       C            1   0
# 79998     NaN     0.0       L            0   0
# 79999     0.0     0.0       C            1   0
#
# [80000 rows x 49 columns]

# %%
print(gameDf.shape)
print(dataDict.shape)
# Out:
# (80000, 49)
# (49, 2)

# %%
dic = dict(zip(dataDict.values[:, 1], dataDict.values[:, 0]))

# %%
dic['Average tenure of active revolving credit cards (in days)']
# Out:
# 'mvar25'

# %%
#remove ID column
del gameDf[dic['Application ID (primary key)']]
del dic['Application ID (primary key)']

leaderAppID = leaderDf['application_key']
del leaderDf['application_key']
leaderX = leaderDf.copy()

# %%
gameX = gameDf.iloc[:,:-1]
gameY = gameDf.iloc[:,-1]

# %%
range(gameDf["mvar47"].shape[0])
# Out:
# range(0, 80000)

# %%
gameX["mvar47"][0]
# Out:
# 'C'

# %%
#one hot encoding C=0 L=1
gameX['mvar47'] = pd.get_dummies(gameX['mvar47'])
leaderX['mvar47'] = pd.get_dummies(leaderX['mvar47'])

# %%
gameX["mvar47"].dtype
# Out:
# dtype('uint8')

# %% [markdown]
# # Synthesis begins

# %%
gameX['mvar5'] = (1+gameX['mvar3'])*(1+gameX['mvar4'])*(1+gameX['mvar5'])
leaderX['mvar5'] = (1+leaderX['mvar3'])*(1+leaderX['mvar4'])*(1+leaderX['mvar5'])

# %%
# gameX['mvar7'] = (gameX['mvar7'] + gameX['mvar8'])#/(1+gameX['mvar6'])
# leaderX['mvar7'] = (leaderX['mvar7'] + leaderX['mvar8'])#/(1+leaderX['mvar6'])

# %%
# df = gameX.copy()
# df['mvar16'][df['mvar16'].isnull()] = -1
# df['mvar17'][df['mvar17'].isnull()] = -1
# df['mvar18'][df['mvar18'].isnull()] = -1

# df['mvar16'] = df['mvar16']+df['mvar17']+df['mvar18']

# df['mvar16'][df['mvar16']>0] = 0.5265
# df['mvar16'][df['mvar16']==0] = 0.1763
# df['mvar16'][df['mvar16']==-1] = 0.2594
# df['mvar16'][df['mvar16']==-2] = 0.2594
# df['mvar16'][df['mvar16']==-3] = 0.4423

# gameX = df.copy()

# df = leaderX.copy()
# df['mvar16'][df['mvar16'].isnull()] = -1
# df['mvar17'][df['mvar17'].isnull()] = -1
# df['mvar18'][df['mvar18'].isnull()] = -1

# df['mvar16'] = df['mvar16']+df['mvar17']+df['mvar18']

# df['mvar16'][df['mvar16']>0] = 0.5265
# df['mvar16'][df['mvar16']==0] = 0.1763
# df['mvar16'][df['mvar16']==-1] = 0.2594
# df['mvar16'][df['mvar16']==-2] = 0.2594
# df['mvar16'][df['mvar16']==-3] = 0.4423

# leaderX = df.copy()

# %%
# gameX['mvar23'] = gameX['mvar23'] - gameX['mvar22']
# leaderX['mvar23'] = leaderX['mvar23'] - leaderX['mvar22']

# %%
df = gameX.copy()
df['mvar26'][df['mvar26'].isnull()] = -365
df['mvar27'][df['mvar27'].isnull()] = -365
df['mvar26'] = (df['mvar26']+df['mvar27'])/2/365
df['mvar26'] = df['mvar26'].astype('int64')

df[df['mvar26']<0] = 0.4026
df['mvar26'][(df['mvar26']>=0) & (df['mvar26']<=5)] = 0.3243
df['mvar26'][df['mvar26']>5] = 0.1562

gameX = df.copy()

df = leaderX.copy()
df['mvar26'][df['mvar26'].isnull()] = -365
df['mvar27'][df['mvar27'].isnull()] = -365
df['mvar26'] = (df['mvar26']+df['mvar27'])/2/365
df['mvar26'] = df['mvar26'].astype('int64')

df[df['mvar26']<0] = 0.4026
df['mvar26'][(df['mvar26']>=0) & (df['mvar26']<=5)] = 0.3243
df['mvar26'][df['mvar26']>5] = 0.1562

leaderX = df.copy()
# Out:
# /home/ekka/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ekka/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ekka/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ekka/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
#drop
df = gameX.copy() 
leader_df = leaderX.copy()
drop_target = ['mvar27']
#number of misssing values
# for i in df.columns:
#     if (100*(80000-gameDf[i].describe()['count'])/80000) >

# %%
for i in drop_target:
    del df[i]
    del leader_df[i]

# %%
leader_df.columns
# Out:
# Index(['mvar1', 'mvar2', 'mvar3', 'mvar4', 'mvar5', 'mvar6', 'mvar7', 'mvar8',
#        'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13', 'mvar14', 'mvar15',
#        'mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20', 'mvar21', 'mvar22',
#        'mvar23', 'mvar24', 'mvar25', 'mvar26', 'mvar28', 'mvar29', 'mvar30',
#        'mvar31', 'mvar32', 'mvar33', 'mvar34', 'mvar35', 'mvar36', 'mvar37',
#        'mvar38', 'mvar39', 'mvar40', 'mvar41', 'mvar42', 'mvar43', 'mvar44',
#        'mvar45', 'mvar46', 'mvar47'],
#       dtype='object')

# %%
gameX = df
leaderX = leader_df

# %% [markdown]
# # Synthesis Ends

# %%
#Missing values median
gameX.fillna(gameX.mean(),inplace = True)
leaderX.fillna(gameX.mean(),inplace = True)

# gameX.fillna(0,inplace = True)
# leaderX.fillna(0,inplace = True)
# Out:
#            mvar1      mvar2    mvar3    mvar4   mvar5         mvar6  \
# 0      1753.0000   0.500100   0.0000   0.0000  0.0000    206.000000
# 1      1894.0000   1.970100   0.0000   0.0000  0.0000    297.000000
# 2      1774.0000   0.171800   0.0000   0.0000  0.0000    197.000000
# 3      1586.0000   0.112300   5.2990   0.0000  0.0000   1326.791111
# 4      1832.0000   1.444200   0.0000   0.0000  0.0000    179.000000
# 5      1838.0000   0.054400   0.2410   0.0000  0.0000    882.000000
# 6      1743.0000   1.075300   0.2720   0.0000  0.0000    397.000000
# 7      1935.0000   0.560100   0.0000   0.0000  0.0000    496.000000
# 8      1885.0000   0.081100   0.0000   0.0000  0.0000   7369.000000
# 9      1730.0000   0.744400   0.0000   0.0000  0.0000      0.000000
# 10     1731.0000   0.509700   0.0000   0.0000  0.0000   2433.000000
# 11     1755.0000   0.301300   0.0000   0.0000  0.0000    261.000000
# 12     1739.0000   2.290900   0.0000   0.0000  0.0000      0.000000
# 13     1562.0000   0.000000  34.6110   3.7845  0.0000   1326.791111
# 14     1798.0000   5.082500   0.0000   0.0000  0.0000    259.000000
# 15        0.4026   0.402600   0.4026   0.4026  0.4026      0.402600
# 16     1789.0000   0.000000   1.4280   0.0000  0.0000   2478.000000
# 17     1862.0000   0.240100   0.0000   0.0000  0.0000   1487.000000
# 18     1767.0000   0.300100   1.5140   0.0000  0.0000    991.000000
# 19     1802.0000   0.636400   0.0000   0.0000  0.0000     96.000000
# 20     1780.0000   1.955900   0.0000   0.0000  0.0000    191.000000
# 21     1714.0000   2.266400   0.0000   0.0000  0.0000     31.000000
# 22     1923.0000   0.088000   0.0000   0.0000  0.0000   5946.000000
# 23     1743.0000   1.720800   2.2950   0.0000  0.0000    159.000000
# 24     1700.0000   1.660500   0.0000   0.0000  0.0000      0.000000
# 25     1922.0000   1.011805   0.0000   0.0000  0.0000   4524.000000
# 26     1777.0000   0.412000   0.0000   0.0000  0.0000    369.000000
# 27     1811.0000   0.911700   0.4100   0.0000  0.4100    297.000000
# 28     1658.0000   2.382900  37.1270  10.3678  0.0000      0.000000
# 29     1827.0000   0.280100   0.0000   0.0000  0.0000    678.000000
# ...          ...        ...      ...      ...     ...           ...
# 24970  1734.0000   0.927900   0.5200   0.0000  0.0000    256.000000
# 24971  1849.0000   1.830500   0.0000   0.0000  0.0000   2251.000000
# 24972  1739.0000   1.525100   2.7270   0.0000  2.7270      8.000000
# 24973     0.4026   0.402600   0.4026   0.4026  0.4026      0.402600
# 24974  1709.0000   3.680100   7.5830   3.1371  0.0000    297.000000
# 24975  1890.0000   0.000000   0.0000   0.0000  0.0000   1982.000000
# 24976  1727.0000   1.844800  15.1810   0.0000  0.0000   2234.000000
# 24977  1789.0000   1.299400   0.0000   0.0000  0.0000    364.000000
# 24978  1706.0000   0.499700   0.0000   0.0000  0.0000     98.000000
# 24979  1638.0000   4.680200  16.7510   2.6642  0.0000   1326.791111
# 24980  1855.0000   1.996500   0.0000   0.0000  0.0000    350.000000
# 24981  1790.0000   0.205000   0.0000   0.0000  0.0000    237.000000
# 24982  1546.0000   0.349100  50.8030   4.2695  0.0000   1326.791111
# 24983  1777.0000   3.962900   0.9680   0.0000  0.0000     14.000000
# 24984  1943.0000   1.011805   0.0000   0.0000  0.0000      0.000000
# 24985  1691.0000   0.166300   1.9790   0.0000  0.0000      0.000000
# 24986  1681.0000   0.173900   9.0060   0.0000  6.5680      0.000000
# 24987  1723.0000   1.057000   0.2850   0.0000  0.0000    248.000000
# 24988  1693.0000   1.214500   0.0000   0.0000  0.0000     18.000000
# 24989     0.4026   0.402600   0.4026   0.4026  0.4026      0.402600
# 24990     0.4026   0.402600   0.4026   0.4026  0.4026      0.402600
# 24991  1740.0000   0.390100   4.3220   0.0000  0.0000    490.000000
# 24992  1651.0000   2.490900   1.3350   0.9108  0.0000      4.000000
# 24993  1729.0000   1.360100   0.2180   0.0000  0.0000      0.000000
# 24994  1730.0000   1.670100   5.5540   0.0000  0.0000    104.000000
# 24995  1715.0000  12.000200   0.0000   0.0000  0.0000   1326.791111
# 24996  1800.0000   0.055100   0.0000   0.0000  0.0000   5946.000000
# 24997  1686.0000   1.330100   2.0250   0.0000  2.0250   1326.791111
# 24998  1826.0000   1.011805   0.4280   0.0000  0.0000   3568.000000
# 24999  1916.0000   0.139400   0.0000   0.0000  0.0000  18889.000000
#
#              mvar7         mvar8          mvar9       mvar10   ...     mvar38  \
# 0      19179.00000    206.000000   14221.000000   19438.0000   ...     1.0000
# 1      19820.00000  19820.000000  176895.000000   66346.0000   ...     3.0000
# 2       2563.00000    877.000000    8869.000000    3637.0000   ...     1.0000
# 3      15922.63461   5751.609254   30449.229689       0.0000   ...     1.0000
# 4       7577.00000    179.000000   21059.000000   20306.0000   ...     3.0000
# 5      14039.00000  10976.000000  278941.000000   74030.0000   ...     4.0000
# 6      16141.00000   3568.000000   69482.000000   56755.0000   ...     6.0000
# 7      44919.00000  17115.000000  124814.000000  124167.0000   ...     9.0000
# 8      19264.00000  19264.000000   59956.000000   26633.0000   ...     1.0000
# 9       2103.00000    582.000000   16429.000000    9197.0000   ...     9.0000
# 10      8673.00000   8673.000000    6739.000000    7388.0000   ...     2.0000
# 11      4051.00000    261.000000     297.000000     261.0000   ...     3.0000
# 12      7620.00000   7620.000000   64983.000000   14067.0000   ...    11.0000
# 13        18.00000   5751.609254     198.000000      18.0000   ...     7.0000
# 14      3359.00000   2973.000000   22099.000000   13507.0000   ...     5.0000
# 15         0.40260      0.402600       0.402600       0.4026   ...     0.4026
# 16     13874.00000  13874.000000   98011.000000   56200.0000   ...     4.0000
# 17     12310.00000   3964.000000    7928.000000   26564.0000   ...     6.0000
# 18      2478.00000   2478.000000    8790.000000    6065.0000   ...     1.0000
# 19     18759.00000  10905.000000   51037.000000   58544.0000   ...     3.0000
# 20     12525.00000  12525.000000   18932.000000   14602.0000   ...     7.0000
# 21      1671.00000     57.000000     396.000000    2582.0000   ...     6.0000
# 22     53893.00000  24739.000000  128435.000000  125679.0000   ...     2.0000
# 23      3621.00000   2323.000000    9018.000000    9649.0000   ...     8.0000
# 24      1037.00000     46.000000     892.000000    1235.0000   ...     5.0000
# 25     15530.00000  14819.000000  116154.000000  100684.0000   ...     3.0000
# 26      6201.00000   6201.000000   66477.000000   34053.0000   ...    12.0000
# 27     27717.00000   9815.000000  110001.000000   69683.0000   ...     3.0000
# 28       396.00000      0.000000    6566.000000    4068.0000   ...    14.0000
# 29      1189.00000   1189.000000     892.000000    2065.0000   ...     3.0000
# ...            ...           ...            ...          ...   ...        ...
# 24970  11643.00000   1524.000000   16748.000000   25359.0000   ...     7.0000
# 24971  33275.00000   7505.000000   44843.000000   47453.0000   ...     2.0000
# 24972   2129.00000    720.000000    5896.000000    5206.0000   ...     6.0000
# 24973      0.40260      0.402600       0.402600       0.4026   ...     0.4026
# 24974   8132.00000    297.000000    1041.000000    6960.0000   ...    32.0000
# 24975  15162.00000  15162.000000   68181.000000   43334.0000   ...     2.0000
# 24976   2754.00000   2234.000000    2676.000000    6539.0000   ...     4.0000
# 24977  17838.00000  17838.000000    8424.000000   22307.0000   ...     5.0000
# 24978    297.00000     98.000000     546.000000     643.0000   ...     7.0000
# 24979   7937.00000   5751.609254    3032.000000   10489.0000   ...     3.0000
# 24980  30203.00000  22656.000000  168999.000000  166720.0000   ...     2.0000
# 24981  18018.00000  13297.000000    3914.000000    1305.0000   ...     5.0000
# 24982  15922.63461   5751.609254    3330.000000       0.0000   ...     8.0000
# 24983  23707.00000  23707.000000   33432.000000   19640.0000   ...    12.0000
# 24984  24775.00000  24775.000000   80772.000000   69483.0000   ...     0.0000
# 24985   9591.00000   2627.000000   46903.000000   30402.0000   ...     5.0000
# 24986   3004.00000   2251.000000    6818.000000    7783.0000   ...     1.0000
# 24987  28479.00000  28479.000000   16352.000000    3117.0000   ...     7.0000
# 24988    100.00000    100.000000     991.000000     118.0000   ...     3.0000
# 24989      0.40260      0.402600       0.402600       0.4026   ...     0.4026
# 24990      0.40260      0.402600       0.402600       0.4026   ...     0.4026
# 24991  29460.00000   9449.000000   42047.000000   31583.0000   ...     3.0000
# 24992   3163.00000      4.000000    1982.000000    3167.0000   ...    10.0000
# 24993   5675.00000    167.000000   15071.000000   10305.0000   ...     5.0000
# 24994   5692.00000    496.000000    4410.000000    8125.0000   ...     5.0000
# 24995    991.00000   5751.609254    8751.000000    1814.0000   ...     1.0000
# 24996  14867.00000   9613.000000   46490.000000   44722.0000   ...     4.0000
# 24997      0.00000   5751.609254    4582.000000       0.0000   ...     0.0000
# 24998  26277.00000   9058.000000   72739.000000   86797.0000   ...     2.0000
# 24999  18889.00000  18889.000000   28343.000000   51174.0000   ...     0.0000
#
#          mvar39      mvar40      mvar41   mvar42   mvar43   mvar44    mvar45  \
# 0      0.000000   57.700697   20.551000  0.42105   3.0000  0.85661  0.146538
# 1      0.000000   57.700697   63.047000  0.00000  15.0000  0.94391  0.000000
# 2      0.000000   57.700697   83.797000  0.33333   3.0000  0.76467  0.000000
# 3      0.132286   57.700697   49.621102  1.50000   0.0000  0.65601  0.146538
# 4      0.000000   96.052000   66.665000  0.00000  23.0000  0.79190  0.000000
# 5      0.000000   57.700697   77.780000  0.00000  21.0000  0.92462  0.000000
# 6      0.000000   57.700697   67.159000  0.00000  14.0000  0.71347  0.000000
# 7      0.000000   57.700697   49.621102  0.00000  15.0000  0.92403  0.000000
# 8      0.000000   57.700697   49.621102  0.00000   5.0000  0.89760  0.000000
# 9      0.000000   57.700697   49.621102  0.05882  14.0000  0.40529  0.146538
# 10     0.000000   57.700697   49.621102  0.23529   1.0000  0.64242  0.000000
# 11     0.000000   57.700697   49.621102  0.33333   2.0000  0.99142  0.146538
# 12     0.000000   57.700697   95.000000  0.05882  16.0000  0.44167  0.146538
# 13     1.000000  124.910000   99.934000  0.87500   1.0000  0.84592  1.000000
# 14     0.000000   57.700697   76.881000  0.05882  13.0000  0.43365  0.000000
# 15     0.402600    0.402600    0.402600  0.40260   0.4026  0.40260  0.402600
# 16     0.000000   57.700697   49.621102  0.05000  13.0000  0.51231  0.146538
# 17     0.000000   57.700697   77.419000  0.00000   7.0000  0.56685  0.000000
# 18     0.000000   57.700697   49.621102  0.10000   3.0000  0.65601  0.146538
# 19     0.000000   57.700697   58.972000  0.00000   9.0000  0.59409  0.000000
# 20     0.000000   57.700697  100.000000  0.00000   7.0000  0.92752  0.000000
# 21     0.000000   57.700697   91.666000  0.37500   5.0000  0.34836  0.146538
# 22     0.000000   57.700697   90.429000  0.00000   9.0000  0.88554  0.000000
# 23     0.000000   57.700697   82.323000  0.10000   9.0000  0.59442  0.146538
# 24     0.000000   57.700697   49.621102  0.20000   5.0000  0.94826  0.146538
# 25     0.000000   57.700697   49.621102  0.00000  12.0000  0.91550  0.000000
# 26     0.000000   57.700697   49.621102  0.03846  23.0000  0.15159  0.146538
# 27     0.000000   57.700697   74.996000  0.00000  15.0000  0.56671  0.000000
# 28     0.000000   57.700697   49.621102  0.57692   8.0000  0.35339  0.146538
# 29     0.000000   57.700697   49.621102  0.00000   2.0000  1.00000  0.146538
# ...         ...         ...         ...      ...      ...      ...       ...
# 24970  0.000000   57.700697   49.621102  0.00000  10.0000  0.38078  0.146538
# 24971  0.000000   57.700697   91.701000  0.00000   4.0000  0.92111  0.000000
# 24972  0.000000  109.251000   94.127000  0.36842  12.0000  0.52903  0.146538
# 24973  0.402600    0.402600    0.402600  0.40260   0.4026  0.40260  0.402600
# 24974  0.000000   81.029000   49.621102  0.59459  11.0000  0.42680  0.146538
# 24975  0.000000   98.043000   55.197000  0.00000  15.0000  0.27143  0.146538
# 24976  0.000000   57.700697   49.621102  0.66667   5.0000  0.87890  0.000000
# 24977  0.000000  109.307000   75.052000  0.15385   8.0000  0.69694  0.000000
# 24978  0.000000   57.700697   49.621102  0.66667   4.0000  1.00000  0.146538
# 24979  1.000000  102.709000   13.882000  0.50000   4.0000  0.72640  0.146538
# 24980  0.000000   57.700697   49.621102  0.00000  12.0000  0.74106  0.000000
# 24981  0.000000   57.700697   49.621102  0.20000   2.0000  0.41582  0.146538
# 24982  0.000000   57.700697   49.621102  0.70370   2.0000  1.00000  1.000000
# 24983  0.000000   57.700697   80.934000  0.04000  15.0000  0.64752  0.146538
# 24984  0.000000   57.700697   49.621102  0.00000   6.0000  0.97068  0.000000
# 24985  0.000000   84.801000   63.855000  0.03448  14.0000  0.43441  0.146538
# 24986  1.000000   96.309000   49.621102  0.71429   2.0000  0.88908  0.000000
# 24987  0.000000   57.700697   49.621102  0.00000   6.0000  0.72344  0.146538
# 24988  0.000000   57.700697   49.621102  0.00000   3.0000  0.36619  0.146538
# 24989  0.402600    0.402600    0.402600  0.40260   0.4026  0.40260  0.402600
# 24990  0.402600    0.402600    0.402600  0.40260   0.4026  0.40260  0.402600
# 24991  0.000000   57.700697   49.621102  0.20000   4.0000  0.88957  1.000000
# 24992  0.000000   57.700697   82.382000  0.61538   3.0000  0.93745  0.146538
# 24993  0.000000   57.700697   49.621102  0.23810  13.0000  0.71866  0.146538
# 24994  0.000000   57.700697   79.485000  0.30769   4.0000  0.93312  0.146538
# 24995  0.000000   57.700697   49.621102  0.07692   4.0000  0.65601  0.146538
# 24996  0.000000   57.700697   49.621102  0.05882   8.0000  0.99859  0.000000
# 24997  0.000000  124.171000   49.621102  0.30000   2.0000  0.77519  0.146538
# 24998  0.000000   57.700697   50.119000  0.03333  11.0000  0.40343  0.146538
# 24999  0.000000   57.700697   49.621102  0.00000   5.0000  0.99663  0.000000
#
#          mvar46  mvar47
# 0      0.000000  0.0000
# 1      0.000000  1.0000
# 2      0.000000  1.0000
# 3      0.134822  1.0000
# 4      0.000000  0.0000
# 5      0.000000  0.0000
# 6      0.000000  0.0000
# 7      0.000000  0.0000
# 8      0.134822  0.0000
# 9      0.000000  1.0000
# 10     0.134822  1.0000
# 11     0.000000  1.0000
# 12     0.000000  1.0000
# 13     1.000000  1.0000
# 14     0.000000  1.0000
# 15     0.402600  0.4026
# 16     0.134822  0.0000
# 17     0.000000  1.0000
# 18     0.134822  1.0000
# 19     0.000000  1.0000
# 20     0.000000  1.0000
# 21     0.000000  1.0000
# 22     0.000000  1.0000
# 23     0.000000  1.0000
# 24     0.000000  0.0000
# 25     0.000000  0.0000
# 26     0.134822  1.0000
# 27     0.000000  1.0000
# 28     2.000000  1.0000
# 29     0.134822  1.0000
# ...         ...     ...
# 24970  0.000000  0.0000
# 24971  0.000000  0.0000
# 24972  0.000000  1.0000
# 24973  0.402600  0.4026
# 24974  2.000000  1.0000
# 24975  0.000000  1.0000
# 24976  0.000000  1.0000
# 24977  0.000000  0.0000
# 24978  0.000000  1.0000
# 24979  0.000000  1.0000
# 24980  0.134822  0.0000
# 24981  0.000000  1.0000
# 24982  1.000000  1.0000
# 24983  0.000000  0.0000
# 24984  0.134822  1.0000
# 24985  0.000000  1.0000
# 24986  0.000000  1.0000
# 24987  0.000000  1.0000
# 24988  0.134822  1.0000
# 24989  0.402600  0.4026
# 24990  0.402600  0.4026
# 24991  0.000000  0.0000
# 24992  0.000000  0.0000
# 24993  0.000000  1.0000
# 24994  0.000000  1.0000
# 24995  0.000000  1.0000
# 24996  0.000000  0.0000
# 24997  0.134822  0.0000
# 24998  0.000000  1.0000
# 24999  0.000000  1.0000
#
# [25000 rows x 46 columns]

# %%
#LR

# %%
from sklearn import preprocessing as prep

scaler_list = []
for i in gameX.columns:
    scaler_list.append(prep.StandardScaler().fit(gameX[i]))
    
# prep.StandardScaler()
# Out:
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
gameX_scaled = gameX.copy()

for i in enumerate(gameX_scaled.columns):
    gameX_scaled[i[1]] = scaler_list[i[0]].transform(gameX_scaled[i[1]])
# Out:
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
leaderX_scaled = leaderX.copy()

for i in enumerate(leaderX_scaled.columns):
    leaderX_scaled[i[1]] = scaler_list[i[0]].transform(leaderX_scaled[i[1]])
# Out:
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/ekka/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=1, solver='lbfgs', multi_class='multinomial').fit(gameX_scaled, gameY)

# %%
pred1 = clf.predict_proba(leaderX_scaled)

# %%
clf.coef_
# Out:
# array([[-0.23254498,  0.12911522,  0.02314096, -0.01349574, -0.02214058,
#         -0.05890112,  0.09286405, -0.01314557,  0.05988206, -0.19265974,
#         -0.00931814,  0.04132023, -0.12685122,  0.00379907, -0.04532831,
#          0.02927441, -0.04275745,  0.0917262 , -0.01789015,  0.09849082,
#          0.07070302,  0.03321807,  0.03443124, -0.00086519, -0.07157274,
#          0.04013005, -0.0241332 , -0.02164531, -0.01712484, -0.01577965,
#          0.06094214, -0.0145639 ,  0.07336454,  0.04002169,  0.05847573,
#         -0.15066967,  0.04693071,  0.0037816 ,  0.08108407,  0.04245738,
#          0.12351599, -0.13275628, -0.0075014 ,  0.04811523,  0.04892993,
#          0.22590358]])

# %%
clf.coef_.shape
# Out:
# (1, 46)

# %%
#Method 3

# %%
#current

# %%
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn import cross_validation, metrics   #Additional scklearn functions
from sklearn.grid_search import GridSearchCV   #Perforing grid search

import time

# %%
def modelfit(alg, dtrainX, dtrainY, predictors, useTrainCV=True, cv_folds=4, early_stopping_rounds=50):
    
    if useTrainCV:
        xgb_param = alg.get_xgb_params()
#         xgb_param['num_class']=2
        xgtrain = xgb.DMatrix(dtrainX[predictors].values, label=dtrainY.values)
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,
             early_stopping_rounds=early_stopping_rounds,stratified=True)
        alg.set_params(n_estimators=cvresult.shape[0])
    
    #Fit the algorithm on the data
    alg.fit(dtrainX[predictors], dtrainY ,eval_metric='error')
        
    #Predict training set:
    dtrain_predictions = alg.predict(dtrainX[predictors])
    dtrain_predprob = alg.predict_proba(dtrainX[predictors])[:,1]
        
    #Print model report:
    print ("\nModel Report")
    print ("Accuracy : %.4g" % metrics.accuracy_score(dtrainY.values, dtrain_predictions))
    #print ("AUC Score (Train): %f" % metrics.roc_auc_score(dtrain[target], dtrain_predprob))
                    
    #feat_imp = pd.Series(alg.booster().get_fscore()).sort_values(ascending=False)
    #feat_imp.plot(kind='bar', title='Feature Importances')
    #plt.ylabel('Feature Importance Score')

# %%
#Choose all predictors except target & IDcols
t=time.time()
predictors = [x for x in gameX.columns]
xgb1 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=4, #4
 min_child_weight=1,
 gamma=0,
reg_alpha = 0.05,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)

modelfit(xgb1, gameX, gameY, predictors)

print('time',time.time()-t)
# Out:
# Model Report
# Accuracy : 0.8031
# time 59.74672055244446

# %%
# XGB feature imp
plt.figure(figsize=(20, 4))
plt.bar(range(1, len(xgb1.feature_importances_)+1), xgb1.feature_importances_)
plt.xticks(range(1, len(xgb1.feature_importances_)), gameX.columns, rotation = 30)
plt.show()

# %%
# XGB feature imp
plt.figure(figsize=(20, 4))
plt.bar(range(1, len(xgb1.feature_importances_)+1), xgb1.feature_importances_)
plt.xticks(range(1, len(xgb1.feature_importances_)+1))
plt.show()

# %%
pred2 = xgb1.predict_proba(leaderX)

# %%
pred1 = pd.DataFrame(pred1)
pred1['application_key'] = leaderAppID
print(pred1.shape)

pred2= pd.DataFrame(pred2)
pred2['application_key'] = leaderAppID
pred2.shape
# Out:
# (25000, 3)
# (25000, 3)

# %%
pred1
# Out:
#               0         1  application_key
# 0      0.805953  0.194047           350053
# 1      0.814798  0.185202           350054
# 2      0.690012  0.309988           350055
# 3      0.484395  0.515605           350056
# 4      0.786378  0.213622           350057
# 5      0.895944  0.104056           350058
# 6      0.824150  0.175850           350059
# 7      0.913333  0.086667           350060
# 8      0.888937  0.111063           350061
# 9      0.660489  0.339511           350062
# 10     0.748244  0.251756           350063
# 11     0.658690  0.341310           350064
# 12     0.598820  0.401180           350065
# 13     0.351856  0.648144           350066
# 14     0.630162  0.369838           350067
# 15     0.547285  0.452715           350068
# 16     0.890880  0.109120           350069
# 17     0.750293  0.249707           350070
# 18     0.690454  0.309546           350071
# 19     0.749010  0.250990           350072
# 20     0.655203  0.344797           350073
# 21     0.576396  0.423604           350074
# 22     0.868260  0.131740           350075
# 23     0.632694  0.367306           350076
# 24     0.638418  0.361582           350077
# 25     0.911660  0.088340           350078
# 26     0.713747  0.286253           350079
# 27     0.795531  0.204469           350080
# 28     0.166935  0.833065           350081
# 29     0.710889  0.289111           350082
# ...         ...       ...              ...
# 24970  0.728927  0.271073           375023
# 24971  0.812861  0.187139           375024
# 24972  0.519807  0.480193           375025
# 24973  0.547285  0.452715           375026
# 24974  0.332155  0.667845           375027
# 24975  0.806560  0.193440           375028
# 24976  0.665297  0.334703           375029
# 24977  0.804608  0.195392           375030
# 24978  0.596608  0.403392           375031
# 24979  0.472976  0.527024           375032
# 24980  0.922078  0.077922           375033
# 24981  0.701327  0.298673           375034
# 24982  0.437983  0.562017           375035
# 24983  0.720221  0.279779           375036
# 24984  0.826380  0.173620           375037
# 24985  0.551238  0.448762           375038
# 24986  0.579872  0.420128           375039
# 24987  0.615924  0.384076           375040
# 24988  0.539457  0.460543           375041
# 24989  0.547285  0.452715           375042
# 24990  0.547285  0.452715           375043
# 24991  0.818910  0.181090           375044
# 24992  0.583733  0.416267           375045
# 24993  0.603559  0.396441           375046
# 24994  0.658967  0.341033           375047
# 24995  0.472732  0.527268           375048
# 24996  0.872474  0.127526           375049
# 24997  0.737880  0.262120           375050
# 24998  0.793153  0.206847           375051
# 24999  0.883190  0.116810           375052
#
# [25000 rows x 3 columns]

# %%
pred2
# Out:
#               0         1  application_key
# 0      0.952616  0.047384           350053
# 1      0.955737  0.044263           350054
# 2      0.878236  0.121764           350055
# 3      0.328021  0.671979           350056
# 4      0.927535  0.072465           350057
# 5      0.994285  0.005715           350058
# 6      0.927642  0.072358           350059
# 7      0.994785  0.005215           350060
# 8      0.992848  0.007152           350061
# 9      0.743476  0.256524           350062
# 10     0.928640  0.071360           350063
# 11     0.784973  0.215027           350064
# 12     0.590544  0.409456           350065
# 13     0.163392  0.836608           350066
# 14     0.723303  0.276697           350067
# 15     0.598292  0.401708           350068
# 16     0.982500  0.017499           350069
# 17     0.921487  0.078513           350070
# 18     0.862544  0.137456           350071
# 19     0.902283  0.097717           350072
# 20     0.785944  0.214056           350073
# 21     0.649620  0.350380           350074
# 22     0.985719  0.014281           350075
# 23     0.776092  0.223908           350076
# 24     0.692095  0.307905           350077
# 25     0.995368  0.004632           350078
# 26     0.859806  0.140194           350079
# 27     0.937731  0.062269           350080
# 28     0.085867  0.914133           350081
# 29     0.881950  0.118050           350082
# ...         ...       ...              ...
# 24970  0.891698  0.108302           375023
# 24971  0.971281  0.028719           375024
# 24972  0.564072  0.435928           375025
# 24973  0.598292  0.401708           375026
# 24974  0.472214  0.527786           375027
# 24975  0.982343  0.017657           375028
# 24976  0.727652  0.272348           375029
# 24977  0.956359  0.043641           375030
# 24978  0.646009  0.353991           375031
# 24979  0.425163  0.574837           375032
# 24980  0.988938  0.011062           375033
# 24981  0.873576  0.126424           375034
# 24982  0.363672  0.636328           375035
# 24983  0.755035  0.244965           375036
# 24984  0.981636  0.018364           375037
# 24985  0.567252  0.432748           375038
# 24986  0.734355  0.265645           375039
# 24987  0.660228  0.339772           375040
# 24988  0.557059  0.442941           375041
# 24989  0.598292  0.401708           375042
# 24990  0.598292  0.401708           375043
# 24991  0.954752  0.045248           375044
# 24992  0.553086  0.446914           375045
# 24993  0.695369  0.304631           375046
# 24994  0.775216  0.224784           375047
# 24995  0.483811  0.516189           375048
# 24996  0.984299  0.015701           375049
# 24997  0.806394  0.193606           375050
# 24998  0.944818  0.055182           375051
# 24999  0.988183  0.011817           375052
#
# [25000 rows x 3 columns]

# %%
pred1 = pred1.sort_values(by = 0,kind = 'mergesort',ascending = False)

pred2 = pred2.sort_values(by = 0,kind = 'mergesort',ascending = False)
# pred2 = pred2.sort_values(by = 0,kind = 'mergesort',ascending = True) #true for xgb method3

# %%
cols = pred1.columns.tolist()
cols = cols[-1:] + cols[:-1]
pred1 = pred1[cols]

cols = pred2.columns.tolist()
cols = cols[-1:] + cols[:-1]
pred2 = pred2[cols]

# %%
pred1 = pred1.loc[:,'application_key':]

pred2 = pred2.loc[:,'application_key':]

# %%
submit1 = pred1['application_key'][:10000]
submit1 = pd.DataFrame(submit1)
submit1[0] = 0

submit2 = pred2['application_key'][:10000]
submit2 = pd.DataFrame(submit2)
submit2[0] = 0

# %%
# submit.iloc[-400:, 1] = 1

# %%
submit1
# Out:
#        application_key  0
# 21128           371181  0
# 15911           365964  0
# 13848           363901  0
# 7820            357873  0
# 23338           373391  0
# 8558            358611  0
# 3642            353695  0
# 11401           361454  0
# 21040           371093  0
# 22990           373043  0
# 21731           371784  0
# 18127           368180  0
# 19140           369193  0
# 19883           369936  0
# 23607           373660  0
# 922             350975  0
# 24868           374921  0
# 17058           367111  0
# 22203           372256  0
# 20952           371005  0
# 20083           370136  0
# 22465           372518  0
# 11416           361469  0
# 20760           370813  0
# 16082           366135  0
# 22550           372603  0
# 14150           364203  0
# 17829           367882  0
# 23266           373319  0
# 8016            358069  0
# ...                ... ..
# 19679           369732  0
# 21568           371621  0
# 20690           370743  0
# 15955           366008  0
# 6714            356767  0
# 22591           372644  0
# 12565           362618  0
# 679             350732  0
# 23807           373860  0
# 24983           375036  0
# 13230           363283  0
# 5899            355952  0
# 11163           361216  0
# 12065           362118  0
# 20510           370563  0
# 893             350946  0
# 19805           369858  0
# 15807           365860  0
# 20098           370151  0
# 2353            352406  0
# 7271            357324  0
# 21619           371672  0
# 18853           368906  0
# 13067           363120  0
# 6508            356561  0
# 17146           367199  0
# 4260            354313  0
# 16232           366285  0
# 8671            358724  0
# 23394           373447  0
#
# [10000 rows x 2 columns]

# %%
submit2
# Out:
#        application_key  0
# 22292           372345  0
# 20330           370383  0
# 14148           364201  0
# 11471           361524  0
# 3708            353761  0
# 21956           372009  0
# 2771            352824  0
# 22203           372256  0
# 23797           373850  0
# 193             350246  0
# 190             350243  0
# 4599            354652  0
# 15480           365533  0
# 15268           365321  0
# 19117           369170  0
# 22865           372918  0
# 15982           366035  0
# 22049           372102  0
# 23075           373128  0
# 10881           360934  0
# 8928            358981  0
# 49              350102  0
# 11416           361469  0
# 22631           372684  0
# 24825           374878  0
# 124             350177  0
# 18109           368162  0
# 3303            353356  0
# 2760            352813  0
# 16408           366461  0
# ...                ... ..
# 14473           364526  0
# 21886           371939  0
# 16682           366735  0
# 16527           366580  0
# 9297            359350  0
# 22004           372057  0
# 19047           369100  0
# 6836            356889  0
# 8897            358950  0
# 18890           368943  0
# 9629            359682  0
# 5906            355959  0
# 10486           360539  0
# 11594           361647  0
# 5382            355435  0
# 23825           373878  0
# 13372           363425  0
# 9121            359174  0
# 13820           363873  0
# 24275           374328  0
# 3880            353933  0
# 14127           364180  0
# 19463           369516  0
# 21808           371861  0
# 12707           362760  0
# 371             350424  0
# 20142           370195  0
# 7372            357425  0
# 20208           370261  0
# 11304           361357  0
#
# [10000 rows x 2 columns]

# %%
# no = 262

# submit1.to_csv('flabbergasted_IITGuwahati_'+str(no)+'.csv',header = False, index = False)
submit2.to_csv('flabbergasted_IITGuwahati_'+str(no+1)+'.csv',header = False, index = False)

no+=1

# %%
no
# Out:
# 264

# %%
# XGB feature imp
plt.figure(figsize=(20, 4))
plt.bar(range(1, len(xgb1.feature_importances_)+1), xgb1.feature_importances_)
plt.xticks(range(1, len(xgb1.feature_importances_)+1))
plt.show()
